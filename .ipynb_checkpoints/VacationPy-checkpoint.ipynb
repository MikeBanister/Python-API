# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))

# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import geoviews as gv
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.container { width:75% !important; }</style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        albany  42.6001  -73.9662      9.21        55         100
# 1        1      corciano  43.1290   12.2874     10.14        82          56
# 2        2       mendota  36.7536 -120.3816     16.29        35         100
# 3        3  longyearbyen  78.2186   15.6401     -0.09        93          75
# 4        4  punta arenas -53.1500  -70.9167      9.06        76         100
#
#    Wind Speed Country        Date
# 0        4.57      US  1681851705
# 1        4.12      IT  1681851705
# 2        4.82      US  1681851705
# 3        2.06      SJ  1681851705
# 4        3.60      CL  1681851705

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    frame_width = 1000,
    frame_height = 750,
    color = "City",
)

# Display the map
humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df[(city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21) & (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] < 4.5)].dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 28        28  santiago del estero -27.7951  -64.2615     24.74        51
# 165      165                 tura  25.5198   90.2201     26.26        62
# 188      188            bangalore  12.9762   77.6033     21.90        47
# 321      321                 loei  17.4167  101.5000     25.25        55
# 418      418              sawakin  19.1059   37.3321     25.47        47
# 420      420           pascagoula  30.3658  -88.5561     23.73        37
# 450      450             santa fe -31.6333  -60.7000     22.23        28
# 451      451                bowen -20.0167  148.2333     22.41        83
# 454      454               maceio  -9.6658  -35.7353     26.69        89
# 458      458            rangapara  26.8167   92.6500     25.24        40
# 478      478              illapel -31.6308  -71.1653     21.87        36
# 508      508               mehran  33.1222   46.1646     24.95        34
# 511      511            saint-leu -21.1500   55.2833     24.46        92
# 515      515             havelock  34.8791  -76.9013     26.10        39
#
#      Cloudiness  Wind Speed Country        Date
# 28            0        1.95      AR  1681851705
# 165           3        3.55      IN  1681851705
# 188           0        2.72      IN  1681851705
# 321           0        2.59      TH  1681851705
# 418           0        3.64      SD  1681851705
# 420           0        2.06      US  1681851705
# 450           4        3.58      AR  1681851705
# 451           0        4.40      AU  1681851705
# 454           0        3.60      BR  1681851705
# 458           1        1.59      IN  1681851705
# 478           0        2.76      CL  1681851705
# 508           3        2.75      IR  1681851705
# 511           4        1.62      RE  1681851705
# 515           0        4.12      US  1681851705

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat",  "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
# C:\Users\mikek\AppData\Local\Temp\ipykernel_13756\3269823366.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                     City Country      Lat       Lng  Humidity Hotel Name
# 28   santiago del estero      AR -27.7951  -64.2615        51
# 165                 tura      IN  25.5198   90.2201        62
# 188            bangalore      IN  12.9762   77.6033        47
# 321                 loei      TH  17.4167  101.5000        55
# 418              sawakin      SD  19.1059   37.3321        47
# 420           pascagoula      US  30.3658  -88.5561        37
# 450             santa fe      AR -31.6333  -60.7000        28
# 451                bowen      AU -20.0167  148.2333        83
# 454               maceio      BR  -9.6658  -35.7353        89
# 458            rangapara      IN  26.8167   92.6500        40
# 478              illapel      CL -31.6308  -71.1653        36
# 508               mehran      IR  33.1222   46.1646        34
# 511            saint-leu      RE -21.1500   55.2833        92
# 515             havelock      US  34.8791  -76.9013        39

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "format": "json",
    "filter": "circle:77.6033,12.9762,10000",
    "limit": 1,
}

base_url = "https://api.geoapify.com/v2/places"

response = requests.get(base_url, params = params).json()

# %%
response["features"][0]["properties"]["name"]
# Out:
# 'Taj West End'

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "format": "json",
    "limit": 1,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = row["Lng"]
    lat = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# santiago del estero - nearest hotel: Nuevo Hotel Brístol
# tura - nearest hotel: No hotel found
# bangalore - nearest hotel: Empire Group Of Hotels
# loei - nearest hotel: ภูเรือธารา
# sawakin - nearest hotel: Hotel Halfa
# pascagoula - nearest hotel: Grand Magnolia
# santa fe - nearest hotel: Intersur Hotel
# bowen - nearest hotel: Whitsunday Sands Resort
# maceio - nearest hotel: Maceió Hostel e Pousada
# rangapara - nearest hotel: No hotel found
# illapel - nearest hotel: Domingo Ortiz de Rosas
# mehran - nearest hotel: No hotel found
# saint-leu - nearest hotel: Iloha Seaview Hôtel
# havelock - nearest hotel: Quality Inn Havelock Hwy 70
#                     City Country      Lat       Lng  Humidity  \
# 28   santiago del estero      AR -27.7951  -64.2615        51
# 165                 tura      IN  25.5198   90.2201        62
# 188            bangalore      IN  12.9762   77.6033        47
# 321                 loei      TH  17.4167  101.5000        55
# 418              sawakin      SD  19.1059   37.3321        47
# 420           pascagoula      US  30.3658  -88.5561        37
# 450             santa fe      AR -31.6333  -60.7000        28
# 451                bowen      AU -20.0167  148.2333        83
# 454               maceio      BR  -9.6658  -35.7353        89
# 458            rangapara      IN  26.8167   92.6500        40
# 478              illapel      CL -31.6308  -71.1653        36
# 508               mehran      IR  33.1222   46.1646        34
# 511            saint-leu      RE -21.1500   55.2833        92
# 515             havelock      US  34.8791  -76.9013        39
#
#                       Hotel Name
# 28           Nuevo Hotel Brístol
# 165               No hotel found
# 188       Empire Group Of Hotels
# 321                   ภูเรือธารา
# 418                  Hotel Halfa
# 420               Grand Magnolia
# 450               Intersur Hotel
# 451      Whitsunday Sands Resort
# 454      Maceió Hostel e Pousada
# 458               No hotel found
# 478       Domingo Ortiz de Rosas
# 508               No hotel found
# 511          Iloha Seaview Hôtel
# 515  Quality Inn Havelock Hwy 70

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 750,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
